# %% [markdown]
# # 02 - Modeling

# %% [markdown]
# > Scaffold notebook — fill with data and code.

# %% [markdown]
# ## Setup

# %%
# TODO

# %% [markdown]
# ## Feature engineering

# %%
# TODO

# %% [markdown]
# ## Baseline model

# %%
# TODO

# %% [markdown]
# ## Evaluation

# %%
# TODO
