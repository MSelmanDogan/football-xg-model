# %% [markdown]
# # 01 - Data Preparation

# %% [markdown]
# > Scaffold notebook — fill with data and code.

# %% [markdown]
# ## Setup

# %%
# TODO

# %% [markdown]
# ## Load data

# %%
# TODO

# %% [markdown]
# ## Clean & normalize

# %%
# TODO

# %% [markdown]
# ## Train/val split

# %%
# TODO
